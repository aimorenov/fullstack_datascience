# %% [markdown]
# ## Hotel location: scraping booking.com for location of hotels in top 35 cities to visit in France
#
# In this notebook I :
# -  Scraped the latitude and longitude for all the top 100 hotels found in the [top 35 best cities in France](https://one-week-in.com/35-cities-to-visit-in-france/)
# -  Hotel latitude and longitude is scraped from [booking.com](https://www.booking.com), using the link to the map of each hotel
#
# - For scraping of hotel information, see notebook 02-booking_scrap1.ipynb

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import os
import logging

from bs4 import BeautifulSoup

import scrapy
from scrapy.crawler import CrawlerProcess

from src.booking_scrap2 import *

# %% [markdown]
# ## Scrap2
#
# Use map links for each hotel retrieved from booking.com to obtatin latitude and longitude of hotel

# %%
from src.booking_scrap1 import hotels_links_ls

# %%
# Name of the file where the results will be saved
filename = "scrap2_hotels_topcities_booking.csv"


# If file already exists, delete it before crawling (because Scrapy will concatenate the last and new results otherwise)
if filename in os.listdir('data/processed/'):
        os.remove('data/processed/' + filename)


process = CrawlerProcess(settings = {
    'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)',
    'LOG_LEVEL': logging.INFO,
    "FEEDS": {
        'data/processed/' + filename: {"format": "csv"},
    }
})

# Start the crawling using the spider you defined above
process.crawl(HotelLatLonSpider)
process.start()
# Out:
# 2022-04-17 15:59:35 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2022-04-17 15:59:35 [scrapy.utils.log] INFO: Versions: lxml 4.7.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.1.0, Python 3.9.7 (default, Sep 16 2021, 08:50:36) - [Clang 10.0.0 ], pyOpenSSL 22.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform macOS-10.16-x86_64-i386-64bit
# 2022-04-17 15:59:35 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-04-17 15:59:35 [scrapy.extensions.telnet] INFO: Telnet Password: 68338651a9de89ae
# 2022-04-17 15:59:35 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-04-17 15:59:35 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-04-17 15:59:35 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-04-17 15:59:35 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-04-17 15:59:35 [scrapy.core.engine] INFO: Spider opened
# 2022-04-17 15:59:35 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-04-17 15:59:35 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-04-17 16:00:35 [scrapy.extensions.logstats] INFO: Crawled 197 pages (at 197 pages/min), scraped 196 items (at 196 items/min)
# 2022-04-17 16:01:35 [scrapy.extensions.logstats] INFO: Crawled 385 pages (at 188 pages/min), scraped 385 items (at 189 items/min)
# 2022-04-17 16:18:39 [scrapy.extensions.logstats] INFO: Crawled 479 pages (at 94 pages/min), scraped 479 items (at 94 items/min)
# 2022-04-17 16:36:38 [scrapy.extensions.logstats] INFO: Crawled 487 pages (at 8 pages/min), scraped 484 items (at 5 items/min)
# 2022-04-17 16:54:30 [scrapy.extensions.logstats] INFO: Crawled 494 pages (at 7 pages/min), scraped 494 items (at 10 items/min)
# 2022-04-17 16:54:30 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.booking.com/hotel/fr/clos-margottia-res.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=25&hapos=50&sr_order=popularity&srpvid=6fe3584db6ba0078&srepoch=1650198812&all_sr_blocks=72628902_338718118_2_0_0&highlighted_blocks=72628902_338718118_2_0_0&matching_block_id=72628902_338718118_2_0_0&sr_pri_blocks=72628902_338718118_2_0_0__80104&from=searchresults&map=1> (failed 3 times): User timeout caused connection failure: Getting https://www.booking.com/hotel/fr/clos-margottia-res.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=25&hapos=50&sr_order=popularity&srpvid=6fe3584db6ba0078&srepoch=1650198812&all_sr_blocks=72628902_338718118_2_0_0&highlighted_blocks=72628902_338718118_2_0_0&matching_block_id=72628902_338718118_2_0_0&sr_pri_blocks=72628902_338718118_2_0_0__80104&from=searchresults&map=1 took longer than 180.0 seconds..
# 2022-04-17 16:54:30 [scrapy.downloadermiddlewares.retry] ERROR: Gave up retrying <GET https://www.booking.com/hotel/fr/la-catene-perret.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=4&hapos=29&sr_order=popularity&srpvid=fc7a584d4b940146&srepoch=1650198813&all_sr_blocks=534380501_189201512_2_0_0&highlighted_blocks=534380501_189201512_2_0_0&matching_block_id=534380501_189201512_2_0_0&sr_pri_blocks=534380501_189201512_2_0_0__84650&from_beach_sr=1&from=searchresults&map=1> (failed 3 times): User timeout caused connection failure: Getting https://www.booking.com/hotel/fr/la-catene-perret.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=4&hapos=29&sr_order=popularity&srpvid=fc7a584d4b940146&srepoch=1650198813&all_sr_blocks=534380501_189201512_2_0_0&highlighted_blocks=534380501_189201512_2_0_0&matching_block_id=534380501_189201512_2_0_0&sr_pri_blocks=534380501_189201512_2_0_0__84650&from_beach_sr=1&from=searchresults&map=1 took longer than 180.0 seconds..
# 2022-04-17 16:54:30 [scrapy.core.scraper] ERROR: Error downloading <GET https://www.booking.com/hotel/fr/clos-margottia-res.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=25&hapos=50&sr_order=popularity&srpvid=6fe3584db6ba0078&srepoch=1650198812&all_sr_blocks=72628902_338718118_2_0_0&highlighted_blocks=72628902_338718118_2_0_0&matching_block_id=72628902_338718118_2_0_0&sr_pri_blocks=72628902_338718118_2_0_0__80104&from=searchresults&map=1>
# Traceback (most recent call last):
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/twisted/internet/defer.py", line 1656, in _inlineCallbacks
#     result = current_context.run(
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/twisted/python/failure.py", line 489, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/scrapy/core/downloader/middleware.py", line 44, in process_request
#     return (yield download_func(request=request, spider=spider))
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/twisted/internet/defer.py", line 857, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/scrapy/core/downloader/handlers/http11.py", line 355, in _cb_timeout
#     raise TimeoutError(f"Getting {url} took longer than {timeout} seconds.")
# twisted.internet.error.TimeoutError: User timeout caused connection failure: Getting https://www.booking.com/hotel/fr/clos-margottia-res.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=25&hapos=50&sr_order=popularity&srpvid=6fe3584db6ba0078&srepoch=1650198812&all_sr_blocks=72628902_338718118_2_0_0&highlighted_blocks=72628902_338718118_2_0_0&matching_block_id=72628902_338718118_2_0_0&sr_pri_blocks=72628902_338718118_2_0_0__80104&from=searchresults&map=1 took longer than 180.0 seconds..
# 2022-04-17 16:54:30 [scrapy.core.scraper] ERROR: Error downloading <GET https://www.booking.com/hotel/fr/la-catene-perret.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=4&hapos=29&sr_order=popularity&srpvid=fc7a584d4b940146&srepoch=1650198813&all_sr_blocks=534380501_189201512_2_0_0&highlighted_blocks=534380501_189201512_2_0_0&matching_block_id=534380501_189201512_2_0_0&sr_pri_blocks=534380501_189201512_2_0_0__84650&from_beach_sr=1&from=searchresults&map=1>
# Traceback (most recent call last):
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/twisted/internet/defer.py", line 1656, in _inlineCallbacks
#     result = current_context.run(
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/twisted/python/failure.py", line 489, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/scrapy/core/downloader/middleware.py", line 44, in process_request
#     return (yield download_func(request=request, spider=spider))
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/twisted/internet/defer.py", line 857, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/Users/aura.moreno/Documents/Jedha/jedha_env/lib/python3.9/site-packages/scrapy/core/downloader/handlers/http11.py", line 355, in _cb_timeout
#     raise TimeoutError(f"Getting {url} took longer than {timeout} seconds.")
# twisted.internet.error.TimeoutError: User timeout caused connection failure: Getting https://www.booking.com/hotel/fr/la-catene-perret.en-gb.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQm4AQrIAUjYAQHoAQH4AQuIAgGoAgO4ApiS8JIGwAIB0gIkNWRhYTMwYTItOWFhYi00ODMwLTllYWYtNzJlNmUwY2U5ZjEw2AIG4AIB&sid=07ea44e37c3ad7f03d471796c2929b32&aid=304142&ucfs=1&arphpl=1&checkin=2022-06-04&checkout=2022-06-10&group_adults=2&req_adults=2&no_rooms=1&group_children=0&req_children=0&hpos=4&hapos=29&sr_order=popularity&srpvid=fc7a584d4b940146&srepoch=1650198813&all_sr_blocks=534380501_189201512_2_0_0&highlighted_blocks=534380501_189201512_2_0_0&matching_block_id=534380501_189201512_2_0_0&sr_pri_blocks=534380501_189201512_2_0_0__84650&from_beach_sr=1&from=searchresults&map=1 took longer than 180.0 seconds..
# 2022-04-17 17:11:46 [scrapy.extensions.logstats] INFO: Crawled 504 pages (at 10 pages/min), scraped 500 items (at 6 items/min)
# 2022-04-17 17:18:56 [scrapy.extensions.logstats] INFO: Crawled 511 pages (at 7 pages/min), scraped 510 items (at 10 items/min)
# 2022-04-17 17:19:35 [scrapy.extensions.logstats] INFO: Crawled 591 pages (at 80 pages/min), scraped 590 items (at 80 items/min)
# 2022-04-17 17:20:35 [scrapy.extensions.logstats] INFO: Crawled 758 pages (at 167 pages/min), scraped 756 items (at 166 items/min)
# 2022-04-17 17:21:35 [scrapy.extensions.logstats] INFO: Crawled 929 pages (at 171 pages/min), scraped 929 items (at 173 items/min)
# 2022-04-17 17:25:06 [scrapy.extensions.logstats] INFO: Crawled 990 pages (at 61 pages/min), scraped 985 items (at 56 items/min)
# 2022-04-17 17:25:35 [scrapy.extensions.logstats] INFO: Crawled 1070 pages (at 80 pages/min), scraped 1069 items (at 84 items/min)
# 2022-04-17 17:26:35 [scrapy.extensions.logstats] INFO: Crawled 1247 pages (at 177 pages/min), scraped 1247 items (at 178 items/min)
# 2022-04-17 17:27:35 [scrapy.extensions.logstats] INFO: Crawled 1425 pages (at 178 pages/min), scraped 1425 items (at 178 items/min)
# 2022-04-17 17:28:35 [scrapy.extensions.logstats] INFO: Crawled 1586 pages (at 161 pages/min), scraped 1586 items (at 161 items/min)
# 2022-04-17 17:29:35 [scrapy.extensions.logstats] INFO: Crawled 1767 pages (at 181 pages/min), scraped 1767 items (at 181 items/min)
# 2022-04-17 17:30:35 [scrapy.extensions.logstats] INFO: Crawled 1942 pages (at 175 pages/min), scraped 1940 items (at 173 items/min)
# 2022-04-17 17:31:35 [scrapy.extensions.logstats] INFO: Crawled 2087 pages (at 145 pages/min), scraped 2086 items (at 146 items/min)
# 2022-04-17 17:32:35 [scrapy.extensions.logstats] INFO: Crawled 2243 pages (at 156 pages/min), scraped 2243 items (at 157 items/min)
# 2022-04-17 17:33:35 [scrapy.extensions.logstats] INFO: Crawled 2243 pages (at 0 pages/min), scraped 2243 items (at 0 items/min)
# 2022-04-17 17:34:35 [scrapy.extensions.logstats] INFO: Crawled 2243 pages (at 0 pages/min), scraped 2243 items (at 0 items/min)
# 2022-04-17 17:35:35 [scrapy.extensions.logstats] INFO: Crawled 2261 pages (at 18 pages/min), scraped 2261 items (at 18 items/min)
# 2022-04-17 17:36:36 [scrapy.extensions.logstats] INFO: Crawled 2454 pages (at 193 pages/min), scraped 2452 items (at 191 items/min)
# 2022-04-17 17:37:35 [scrapy.extensions.logstats] INFO: Crawled 2634 pages (at 180 pages/min), scraped 2633 items (at 181 items/min)
# 2022-04-17 17:38:35 [scrapy.extensions.logstats] INFO: Crawled 2820 pages (at 186 pages/min), scraped 2819 items (at 186 items/min)
# 2022-04-17 17:39:20 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-04-17 17:39:20 [scrapy.extensions.feedexport] INFO: Stored csv feed (2949 items) in: data/processed/test.csv
# 2022-04-17 17:39:20 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/exception_count': 55,
#  'downloader/exception_type_count/twisted.internet.error.TimeoutError': 55,
#  'downloader/request_bytes': 4116025,
#  'downloader/request_count': 3004,
#  'downloader/request_method_count/GET': 3004,
#  'downloader/response_bytes': 852250655,
#  'downloader/response_count': 2949,
#  'downloader/response_status_count/200': 2949,
#  'elapsed_time_seconds': 5984.50256,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 4, 17, 15, 39, 20, 363307),
#  'httpcompression/response_bytes': 4687475514,
#  'httpcompression/response_count': 2949,
#  'item_scraped_count': 2949,
#  'log_count/ERROR': 4,
#  'log_count/INFO': 36,
#  'memusage/max': 495431680,
#  'memusage/startup': 164724736,
#  'response_received_count': 2949,
#  'retry/count': 53,
#  'retry/max_reached': 2,
#  'retry/reason_count/twisted.internet.error.TimeoutError': 53,
#  'scheduler/dequeued': 3004,
#  'scheduler/dequeued/memory': 3004,
#  'scheduler/enqueued': 3004,
#  'scheduler/enqueued/memory': 3004,
#  'start_time': datetime.datetime(2022, 4, 17, 13, 59, 35, 860747)}
# 2022-04-17 17:39:20 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### Scraping output

# %%
booking_df_loc = pd.read_csv('data/processed/scrap2_hotels_topcities_booking.csv')
print(booking_df_loc.shape)
booking_df_loc.head()
# Out:
# (2942, 3)
#                                           hotel_name  hotel_lat  hotel_lon
# 0                                      Corne de cerf  48.650225  -2.024735
# 1  LES AMARRES - Maison familiale 3 chambres - Ja...  48.647683  -1.995204
# 2                                            Antinéa  48.655543  -2.005139
# 3            Le RUELLAN charmant duplex proche plage  48.656487  -1.982275
# 4                       Mercure St Malo Front de Mer  48.652567  -2.014242

# %% [markdown]
# ## Merge Scrap 1 and Scrap2

# %%
# Import scrap1 result
booking_df = pd.read_csv('data/processed/scrap1_hotels_topcities_booking-clean.csv')
booking_df.columns
# Out:
# Index(['city', 'suburbs', 'hotel_name', 'link', 'rating', 'room_type', 'price',
#        'stay', 'guests', 'room', 'description', 'location', 'map_link'],
#       dtype='object')

# %%
# Check hotel names match
ls_hot =booking_df['hotel_name'].unique().sort()
ls_loc = booking_df_loc['hotel_name'].unique().sort()
ls_hot == ls_loc
# Out:
# True

# %%
# Merge dfs
booking_df_s3 = booking_df.merge(booking_df_loc, on=['hotel_name'])
print(booking_df_s3.shape)
print(booking_df_s3.columns)
booking_df_s3.head()
# Out:
# (3466, 15)
# Index(['city', 'suburbs', 'hotel_name', 'link', 'rating', 'room_type', 'price',
#        'stay', 'guests', 'room', 'description', 'location', 'map_link',
#        'hotel_lat', 'hotel_lon'],
#       dtype='object')
#          city             suburbs                               hotel_name  \
# 0  Saint Malo  Sillon, Saint Malo                                  Antinéa
# 1  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
# 2  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
# 3  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
# 4  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
#
#                                                 link  rating  \
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...     8.3
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 2  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 3  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 4  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
#
#                              room_type    price      stay    guests  \
# 0  Family Room (2 Adults + 2 Children)  € 1,667  6 nights  2 adults
# 1                            Apartment    € 539  6 nights  2 adults
# 2                            Apartment    € 539  6 nights  2 adults
# 3                            Apartment    € 555  6 nights  2 adults
# 4                            Apartment    € 555  6 nights  2 adults
#
#                         room        description            location  \
# 0                 98 reviews  Free cancellation  1.6 km from centre
# 1  Managed by a private host  Free cancellation  3.3 km from centre
# 2  Managed by a private host  Free cancellation  3.3 km from centre
# 3  Managed by a private host  Free cancellation  3.3 km from centre
# 4  Managed by a private host  Free cancellation  3.3 km from centre
#
#                                             map_link  hotel_lat  hotel_lon
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...  48.655543  -2.005139
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 2  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 3  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 4  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275

# %%
# Output merged dataframe to be uploaded to S3 bucket
booking_df_s3.to_csv('results/scrap_booking_s3.csv', index= False)
