# %% [markdown]
# ## Hotel info: scraping booking.com for top 35 cities to visit in France
#
# In this notebook I :
# -  Retrieved information for the top 100 hotels found in the [top 35 best cities in France](https://one-week-in.com/35-cities-to-visit-in-france/)
# -  Hotel information is scraped from [booking.com](https://www.booking.com)

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import os
import logging

import scrapy
from scrapy.crawler import CrawlerProcess

from src.booking_scrap1 import * # import spiders and list of top 35 cities

# %% [markdown]
# ## Top 35 cities
# Check list of names of cities without french accents

# %%
# Cities_meta_df imported in src.booking_scrap1 from src.cities_weather
top_cities_weather_ls = cities_meta_df['cities_clean'].tolist()

print(len(top_cities_weather_ls))
top_cities_weather_ls[:5]
# Out:
# 35
# ['Mont Saint Michel', 'St Malo', 'Bayeux', 'Le Havre', 'Rouen']

# %% [markdown]
# ## Scrap  hotel information
#
# Carry out two rounds of scraping to obtain the following information for each hotel found in each city:
#
# *Scrap1*
# *   **hotel_name** : hotel name
# *   **suburbs** : if found, indicate city suburb in which hotel is found
# *   **link** : url to its booking.com page
# *   **rating** : score given by the website users
# *   **room_type** : description of available room
# *   **price** : price found for the indicated room and length of stay
# *   **stay** : length of stay chosen in search
# *   **guests** : number of guests (adults) chosen in search
# *   **description** : text description of the hotel
# *   **location** : distance of location to city centre
# *   **map_link** : url to its location on a map
#
#
# *Scrap2*
# * hotel name
# * hotel latitude and longitude

# %% [markdown]
# ### Scrap1
# Following an update of booking.com, could no longer find pagination link
# Solution: create 4 spiders to scrap top 100 best hoteks (booking default ranking)

# %%
# Name of the file where the results will be saved
filename = "scrap1_hotels_topcities_booking.csv"

# If file already exists, delete it before crawling (because Scrapy will concatenate the last and new results otherwise)
if filename in os.listdir('data/interim/'):
        os.remove('data/interim/' + filename)


process = CrawlerProcess(settings = {
    'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)',
    'LOG_LEVEL': logging.INFO,
    "FEEDS": {
        'data/interim/' + filename: {"format": "csv"},
    }
})

# Start the crawling using the spider you defined above
process.crawl(HotelBookingSpider)
process.crawl(HotelBookingSpiderp2)
process.crawl(HotelBookingSpiderp3)
process.crawl(HotelBookingSpiderp4)
process.start()
# Out:
# 2022-04-17 14:33:28 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2022-04-17 14:33:28 [scrapy.utils.log] INFO: Versions: lxml 4.7.1.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.1.0, Python 3.9.7 (default, Sep 16 2021, 08:50:36) - [Clang 10.0.0 ], pyOpenSSL 22.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform macOS-10.16-x86_64-i386-64bit
# 2022-04-17 14:33:28 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet Password: 3cd59203f5bf5a52
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-04-17 14:33:28 [scrapy.core.engine] INFO: Spider opened
# 2022-04-17 14:33:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-04-17 14:33:28 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet Password: 06a41cdeef67b1b6
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-04-17 14:33:28 [scrapy.core.engine] INFO: Spider opened
# 2022-04-17 14:33:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2022-04-17 14:33:28 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet Password: e2c06510481d635a
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-04-17 14:33:28 [scrapy.core.engine] INFO: Spider opened
# 2022-04-17 14:33:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6025
# 2022-04-17 14:33:28 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Chrome/97.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet Password: c461f3e2ab351409
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-04-17 14:33:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-04-17 14:33:28 [scrapy.core.engine] INFO: Spider opened
# 2022-04-17 14:33:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-04-17 14:33:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2022-04-17 14:33:40 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-04-17 14:33:40 [scrapy.extensions.feedexport] INFO: Stored csv feed (747 items) in: results/scrap1_hotels_topcities_booking.csv
# 2022-04-17 14:33:40 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 66747,
#  'downloader/request_count': 37,
#  'downloader/request_method_count/GET': 37,
#  'downloader/response_bytes': 7694715,
#  'downloader/response_count': 37,
#  'downloader/response_status_count/200': 36,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 11.786124,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 4, 17, 12, 33, 40, 625402),
#  'httpcompression/response_bytes': 47430850,
#  'httpcompression/response_count': 36,
#  'item_scraped_count': 747,
#  'log_count/INFO': 20,
#  'memusage/max': 150978560,
#  'memusage/startup': 150978560,
#  'request_depth_max': 1,
#  'response_received_count': 36,
#  'scheduler/dequeued': 37,
#  'scheduler/dequeued/memory': 37,
#  'scheduler/enqueued': 37,
#  'scheduler/enqueued/memory': 37,
#  'start_time': datetime.datetime(2022, 4, 17, 12, 33, 28, 839278)}
# 2022-04-17 14:33:40 [scrapy.core.engine] INFO: Spider closed (finished)
# 2022-04-17 14:33:40 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-04-17 14:33:40 [scrapy.extensions.feedexport] INFO: Stored csv feed (596 items) in: results/scrap1_hotels_topcities_booking.csv
# 2022-04-17 14:33:40 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 66693,
#  'downloader/request_count': 37,
#  'downloader/request_method_count/GET': 37,
#  'downloader/response_bytes': 7538478,
#  'downloader/response_count': 37,
#  'downloader/response_status_count/200': 36,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 11.79015,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 4, 17, 12, 33, 40, 638701),
#  'httpcompression/response_bytes': 44739788,
#  'httpcompression/response_count': 36,
#  'item_scraped_count': 596,
#  'log_count/INFO': 15,
#  'memusage/max': 151117824,
#  'memusage/startup': 151117824,
#  'request_depth_max': 1,
#  'response_received_count': 36,
#  'scheduler/dequeued': 37,
#  'scheduler/dequeued/memory': 37,
#  'scheduler/enqueued': 37,
#  'scheduler/enqueued/memory': 37,
#  'start_time': datetime.datetime(2022, 4, 17, 12, 33, 28, 848551)}
# 2022-04-17 14:33:40 [scrapy.core.engine] INFO: Spider closed (finished)
# 2022-04-17 14:33:41 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-04-17 14:33:41 [scrapy.extensions.feedexport] INFO: Stored csv feed (875 items) in: results/scrap1_hotels_topcities_booking.csv
# 2022-04-17 14:33:41 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 67050,
#  'downloader/request_count': 37,
#  'downloader/request_method_count/GET': 37,
#  'downloader/response_bytes': 7629555,
#  'downloader/response_count': 37,
#  'downloader/response_status_count/200': 36,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 12.755573,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 4, 17, 12, 33, 41, 577319),
#  'httpcompression/response_bytes': 49067300,
#  'httpcompression/response_count': 36,
#  'item_scraped_count': 875,
#  'log_count/INFO': 46,
#  'memusage/max': 150605824,
#  'memusage/startup': 150605824,
#  'request_depth_max': 1,
#  'response_received_count': 36,
#  'scheduler/dequeued': 37,
#  'scheduler/dequeued/memory': 37,
#  'scheduler/enqueued': 37,
#  'scheduler/enqueued/memory': 37,
#  'start_time': datetime.datetime(2022, 4, 17, 12, 33, 28, 821746)}
# 2022-04-17 14:33:41 [scrapy.core.engine] INFO: Spider closed (finished)
# 2022-04-17 14:33:41 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-04-17 14:33:41 [scrapy.extensions.feedexport] INFO: Stored csv feed (833 items) in: results/scrap1_hotels_topcities_booking.csv
# 2022-04-17 14:33:41 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 67231,
#  'downloader/request_count': 37,
#  'downloader/request_method_count/GET': 37,
#  'downloader/response_bytes': 7647343,
#  'downloader/response_count': 37,
#  'downloader/response_status_count/200': 36,
#  'downloader/response_status_count/302': 1,
#  'elapsed_time_seconds': 13.001822,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 4, 17, 12, 33, 41, 831811),
#  'httpcompression/response_bytes': 48330545,
#  'httpcompression/response_count': 36,
#  'item_scraped_count': 833,
#  'log_count/INFO': 41,
#  'memusage/max': 150786048,
#  'memusage/startup': 150786048,
#  'request_depth_max': 1,
#  'response_received_count': 36,
#  'scheduler/dequeued': 37,
#  'scheduler/dequeued/memory': 37,
#  'scheduler/enqueued': 37,
#  'scheduler/enqueued/memory': 37,
#  'start_time': datetime.datetime(2022, 4, 17, 12, 33, 28, 829989)}
# 2022-04-17 14:33:41 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### Scraping output

# %%
booking_df = pd.read_csv('data/interim/scrap1_hotels_topcities_booking.csv')
print(booking_df.shape)
booking_df.head()
# Out:
# (3054, 13)
#          city                   suburbs  \
# 0  Saint Malo        Sillon, Saint Malo
# 1  Saint Malo        Parame, Saint Malo
# 2  Saint Malo  Saint-Servan, Saint Malo
# 3  Saint Malo                Saint Malo
# 4  Saint Malo        Sillon, Saint Malo
#
#                                     hotel_name  \
# 0                                      Antinéa
# 1      Le RUELLAN charmant duplex proche plage
# 2           Résidence Pierre & Vacances Ty Mat
# 3  The Originals City, Hôtel Belem, Saint-Malo
# 4                 Mercure St Malo Front de Mer
#
#                                                 link rating  \
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...    8.3
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...    8.3
# 2  https://www.booking.com/hotel/fr/maevatymat.en...    8.0
# 3  https://www.booking.com/hotel/fr/belem.en-gb.h...    7.5
# 4  https://www.booking.com/hotel/fr/st-malo-front...    7.9
#
#                                            room_type    price      stay  \
# 0                Family Room (2 Adults + 2 Children)  € 1,667  6 nights
# 1                                          Apartment    € 539  6 nights
# 2  Standard Studio with sleeping Alcove and Balco...    € 480  6 nights
# 3                                Comfort Double Room    € 534  6 nights
# 4             Classic Double Room with Side Sea View  € 1,229  6 nights
#
#      guests                       room  \
# 0  2 adults                 98 reviews
# 1  2 adults  Managed by a private host
# 2  2 adults                458 reviews
# 3  2 adults              1,056 reviews
# 4  2 adults                601 reviews
#
#                                 description            location  \
# 0                         Free cancellation  1.6 km from centre
# 1                         Free cancellation  3.3 km from centre
# 2                                       NaN  1.5 km from centre
# 3                                       NaN  4.9 km from centre
# 4  FREE cancellation • No prepayment needed  0.9 km from centre
#
#                                             map_link
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...
# 2  https://www.booking.com/hotel/fr/maevatymat.en...
# 3  https://www.booking.com/hotel/fr/belem.en-gb.h...
# 4  https://www.booking.com/hotel/fr/st-malo-front...

# %%
# Check for unique city values: 
print(booking_df.city.unique().shape)
print(booking_df.city.unique())
# Out:
# (36,)
# ['Saint Malo' 'city' 'Le Havre' 'Le Mont Saint Michel' 'Rouen' 'Amiens'
#  'Bayeux' 'Lille' 'Paris' 'Besançon' 'Strasbourg'
#  '0 properties are available in and around this destination' 'Eguisheim'
#  'Dijon' 'Colmar' 'Grenoble' 'Annecy' 'La Rochelle' 'Biarritz' 'Ariège'
#  'Toulouse' 'Carcassonne' 'Collioure' 'Bayonne' 'Montauban' 'Nîmes'
#  'Bormes-les-Mimosas' 'Aix-en-Provence' 'Cassis' 'Avignon' 'Marseille'
#  'Saintes-Maries-de-la-Mer' 'Aigues-Mortes' 'Gorges du Verdon' 'Lyon'
#  'Uzès']

# %%
# Clean for cases where there is the concatenation line 'city' and the 0 properties found
booking_df_clean = booking_df.copy()

booking_df_clean = booking_df_clean.drop(booking_df_clean[booking_df_clean.city == 'city'].index)
booking_df_clean = booking_df_clean.drop(booking_df_clean[booking_df_clean.city == '0 properties are available in and around this destination'].index)
booking_df_clean.shape
# Out:
# (2951, 13)

# %%
# Check for unique city values: 
print(booking_df_clean.city.unique().shape)
print(booking_df_clean.city.unique())
# Out:
# (34,)
# ['Saint Malo' 'Le Havre' 'Le Mont Saint Michel' 'Rouen' 'Amiens' 'Bayeux'
#  'Lille' 'Paris' 'Besançon' 'Strasbourg' 'Eguisheim' 'Dijon' 'Colmar'
#  'Grenoble' 'Annecy' 'La Rochelle' 'Biarritz' 'Ariège' 'Toulouse'
#  'Carcassonne' 'Collioure' 'Bayonne' 'Montauban' 'Nîmes'
#  'Bormes-les-Mimosas' 'Aix-en-Provence' 'Cassis' 'Avignon' 'Marseille'
#  'Saintes-Maries-de-la-Mer' 'Aigues-Mortes' 'Gorges du Verdon' 'Lyon'
#  'Uzès']

# %%
booking_df_clean.to_csv('data/processed/scrap1_hotels_topcities_booking-clean.csv', index = False)

# %% [markdown]
# ## Scrap2
#
# Go to notebook 02_booking_scrap2.ipynb for scraping of hotel latitude and longitude
