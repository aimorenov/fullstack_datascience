# %% [markdown]
# ## S3 bucket: store hotel and weather info for top 35 cities to visit in France
#
# In this notebook I :
# -  Created an **AWS s3 bucket** containing a single dataframe with weather and hotel information for the [top 35 best cities in France](https://one-week-in.com/35-cities-to-visit-in-france/)
# -  City gps and weather and information was scrapped from the [nominatim](https://nominatim.org/) and [openweathermap](https://openweathermap.org/api/one-call-api) APIs
# -  Hotel information was scraped from [booking.com](https://www.booking.com)

# %% [markdown]
# ## Import libraries

# %%
import boto3
import pandas as pd
import json
import ast

# %% [markdown]
# ## AWS configuration

# %%
from src.credentials import keys_aws

#Create session using AWS access keys and IDs
session = boto3.Session(aws_access_key_id=keys_aws.loc[0,'Access key ID'], 
aws_secret_access_key=keys_aws.loc[0,'Secret access key'])

# %% [markdown]
# ## Ressource session

# %%
s3_resource = session.resource('s3')
bucket_name = "kayak-amorenov"

# %% [markdown]
# ## Create bucket

# %%
# Indicate public-read for read access to AllUsers group
kayak_bucket = s3_resource.create_bucket(Bucket=bucket_name,
ACL = 'public-read',
CreateBucketConfiguration={
        'LocationConstraint': 'eu-west-3'})

kayak_bucket
# Out:
# s3.Bucket(name='kayak-amorenov')

# %%
# Upload bucket policy to make S3 bucket publicly available
file = open("config/AWS_bucket_policy.txt", "r")

policy_file = file.read()
policy_dict = ast.literal_eval(policy_file)

policy_dict
# Out:
# {'Version': '2012-10-17',
#  'Statement': [{'Sid': 'PublicRead',
#    'Effect': 'Allow',
#    'Principal': '*',
#    'Action': ['s3:GetObject', 's3:GetObjectVersion'],
#    'Resource': ['arn:aws:s3:::DOC-EXAMPLE-BUCKET/*']}]}

# %%
# Indicate bucket name inside policy
policy_dict['Statement'][0]['Resource'][0] = 'arn:aws:s3:::{}/*'.format(bucket_name)

policy_dict
# Out:
# {'Version': '2012-10-17',
#  'Statement': [{'Sid': 'PublicRead',
#    'Effect': 'Allow',
#    'Principal': '*',
#    'Action': ['s3:GetObject', 's3:GetObjectVersion'],
#    'Resource': ['arn:aws:s3:::kayak-amorenov/*']}]}

# %%
# Update bucket policy 
bucket_policy = s3_resource.BucketPolicy(bucket_name)

bucket_policy_new = json.dumps(policy_dict)
bucket_policy.put(Policy=bucket_policy_new)
# Out:
# {'ResponseMetadata': {'RequestId': 'QQR62Z3Y2WF7FT6E',
#   'HostId': '3Ik4kP7YzNHKqyxw1KmG9ORHZeg2NzL8NBoQVQ7TDQueL1uKobr4lUVMzDDlcuo//Rf9TIQlGe4=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': '3Ik4kP7YzNHKqyxw1KmG9ORHZeg2NzL8NBoQVQ7TDQueL1uKobr4lUVMzDDlcuo//Rf9TIQlGe4=',
#    'x-amz-request-id': 'QQR62Z3Y2WF7FT6E',
#    'date': 'Sun, 17 Apr 2022 16:17:26 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1}}

# %% [markdown]
# ## Import data for bucket

# %%
# Import output from weather scraping
weather_df_s3 = pd.read_csv('results/top_35_cities_france_weather_gps.csv')
print(weather_df_s3.shape)
weather_df_s3.head()
# Out:
# (280, 33)
#        lat     lon      timezone  timezone_offset          dt     sunrise  \
# 0  45.3314  1.0301  Europe/Paris             7200  1649588400  1649567987
# 1  45.3314  1.0301  Europe/Paris             7200  1649674800  1649654278
# 2  45.3314  1.0301  Europe/Paris             7200  1649761200  1649740570
# 3  45.3314  1.0301  Europe/Paris             7200  1649847600  1649826862
# 4  45.3314  1.0301  Europe/Paris             7200  1649934000  1649913155
#
#        sunset    moonrise     moonset  moon_phase  ...  temp_night  temp_eve  \
# 0  1649615654  1649589840  1649558640        0.28  ...        9.96     12.32
# 1  1649702130  1649680200  1649647080        0.32  ...       12.35     16.73
# 2  1649788607  1649770800  1649735160        0.35  ...       12.70     14.65
# 3  1649875084  1649861400  1649823000        0.38  ...       10.42     10.74
# 4  1649961561  1649952120  1649910660        0.41  ...       13.58     16.08
#
#    temp_morn  feels_like_day  feels_like_night  feels_like_eve  \
# 0       1.02           12.08              8.96           11.15
# 1       8.05           16.11             11.10           15.95
# 2      10.94           16.61             12.01           14.29
# 3      10.96           11.64             10.02           10.38
# 4      10.33           20.48             13.47           16.04
#
#   feels_like_morn    Day  rain    Search_Name
# 0           -0.95  Today   NaN  Aigues Mortes
# 1            5.44  Day_1   NaN  Aigues Mortes
# 2            9.66  Day_2  0.15  Aigues Mortes
# 3           10.38  Day_3  2.34  Aigues Mortes
# 4            9.95  Day_4  2.72  Aigues Mortes
#
# [5 rows x 33 columns]

# %%
# Import output from hotels  scraping
booking_df_s3 = pd.read_csv('results/scrap_booking_s3.csv')
print(booking_df_s3.shape)
booking_df_s3.head()
# Out:
# (3466, 15)
#          city             suburbs                               hotel_name  \
# 0  Saint Malo  Sillon, Saint Malo                                  Antinéa
# 1  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
# 2  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
# 3  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
# 4  Saint Malo  Parame, Saint Malo  Le RUELLAN charmant duplex proche plage
#
#                                                 link  rating  \
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...     8.3
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 2  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 3  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 4  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
#
#                              room_type    price      stay    guests  \
# 0  Family Room (2 Adults + 2 Children)  € 1,667  6 nights  2 adults
# 1                            Apartment    € 539  6 nights  2 adults
# 2                            Apartment    € 539  6 nights  2 adults
# 3                            Apartment    € 555  6 nights  2 adults
# 4                            Apartment    € 555  6 nights  2 adults
#
#                         room        description            location  \
# 0                 98 reviews  Free cancellation  1.6 km from centre
# 1  Managed by a private host  Free cancellation  3.3 km from centre
# 2  Managed by a private host  Free cancellation  3.3 km from centre
# 3  Managed by a private host  Free cancellation  3.3 km from centre
# 4  Managed by a private host  Free cancellation  3.3 km from centre
#
#                                             map_link  hotel_lat  hotel_lon
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...  48.655543  -2.005139
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 2  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 3  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 4  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275

# %%
# Homogenize city names to be able to merge dataframes if necessary
from src.cities_weather import cities_meta_df
print(cities_meta_df.shape)
print(cities_meta_df.head())

weather_df_s3.rename(columns={"Search_Name" : "city"}, inplace=True)
booking_df_s3.rename(columns={"city":"city_clean"}, inplace=True)
# Out:
# (35, 2)
#                 city         city_clean
# 0  Mont Saint Michel  Mont Saint Michel
# 1         Saint-Malo            St Malo
# 2             Bayeux             Bayeux
# 3           Le Havre           Le Havre
# 4              Rouen              Rouen

# %%
weather_df_s3_clean = weather_df_s3.merge(cities_meta_df, how='left', on='city')
booking_df_s3_clean = booking_df_s3.merge(cities_meta_df, how='left', on='city_clean')

print(weather_df_s3_clean.columns)
print(booking_df_s3_clean.columns)
# Out:
# Index(['lat', 'lon', 'timezone', 'timezone_offset', 'dt', 'sunrise', 'sunset',
#        'moonrise', 'moonset', 'moon_phase', 'pressure', 'humidity',
#        'dew_point', 'wind_speed', 'wind_deg', 'wind_gust', 'weather', 'clouds',
#        'pop', 'uvi', 'temp_day', 'temp_min', 'temp_max', 'temp_night',
#        'temp_eve', 'temp_morn', 'feels_like_day', 'feels_like_night',
#        'feels_like_eve', 'feels_like_morn', 'Day', 'rain', 'city',
#        'city_clean'],
#       dtype='object')
# Index(['city_clean', 'suburbs', 'hotel_name', 'link', 'rating', 'room_type',
#        'price', 'stay', 'guests', 'room', 'description', 'location',
#        'map_link', 'hotel_lat', 'hotel_lon', 'city'],
#       dtype='object')

# %% [markdown]
# ## Upload data to bucket

# %%
# Upload file to bucket
weathercsv_s3 = weather_df_s3_clean.to_csv(index=False)
booking_csv_s3 = booking_df_s3_clean.to_csv(index=False)

put_object = kayak_bucket.put_object(Key="top35cities_france_scrap_weather7d.csv", Body=weathercsv_s3)
put_object = kayak_bucket.put_object(Key="top35cities_france_scrap_hotelsbooking.csv", Body=booking_csv_s3)

# %% [markdown]
# ## Verify public access to bucket

# %%
# Verify public access to created bucket: download file
# Additionally checked on own aws account (see screenshot of aws in reports/figures/01-Kayak_aws_bucket_creation.png)

test_bucket_weather = pd.read_csv('https://kayak-amorenov.s3.eu-west-3.amazonaws.com/top35cities_france_scrap_weather7d.csv')
test_bucket_booking = pd.read_csv('https://kayak-amorenov.s3.eu-west-3.amazonaws.com/top35cities_france_scrap_hotelsbooking.csv')

print(weather_df_s3_clean.shape)
print(test_bucket_weather.shape)


print(booking_df_s3_clean.shape)
print(test_bucket_booking.shape)
# Out:
# (280, 34)
# (280, 34)
# (3466, 16)
# (3466, 16)

# %%
test_bucket_weather.head()
# Out:
#        lat     lon      timezone  timezone_offset          dt     sunrise  \
# 0  45.3314  1.0301  Europe/Paris             7200  1649588400  1649567987
# 1  45.3314  1.0301  Europe/Paris             7200  1649674800  1649654278
# 2  45.3314  1.0301  Europe/Paris             7200  1649761200  1649740570
# 3  45.3314  1.0301  Europe/Paris             7200  1649847600  1649826862
# 4  45.3314  1.0301  Europe/Paris             7200  1649934000  1649913155
#
#        sunset    moonrise     moonset  moon_phase  ...  temp_eve  temp_morn  \
# 0  1649615654  1649589840  1649558640        0.28  ...     12.32       1.02
# 1  1649702130  1649680200  1649647080        0.32  ...     16.73       8.05
# 2  1649788607  1649770800  1649735160        0.35  ...     14.65      10.94
# 3  1649875084  1649861400  1649823000        0.38  ...     10.74      10.96
# 4  1649961561  1649952120  1649910660        0.41  ...     16.08      10.33
#
#    feels_like_day  feels_like_night  feels_like_eve  feels_like_morn    Day  \
# 0           12.08              8.96           11.15            -0.95  Today
# 1           16.11             11.10           15.95             5.44  Day_1
# 2           16.61             12.01           14.29             9.66  Day_2
# 3           11.64             10.02           10.38            10.38  Day_3
# 4           20.48             13.47           16.04             9.95  Day_4
#
#    rain           city     city_clean
# 0   NaN  Aigues Mortes  Aigues Mortes
# 1   NaN  Aigues Mortes  Aigues Mortes
# 2  0.15  Aigues Mortes  Aigues Mortes
# 3  2.34  Aigues Mortes  Aigues Mortes
# 4  2.72  Aigues Mortes  Aigues Mortes
#
# [5 rows x 34 columns]

# %%
test_bucket_booking.head()
# Out:
#    Unnamed: 0  city_clean             suburbs  \
# 0           0  Saint Malo  Sillon, Saint Malo
# 1           1  Saint Malo  Parame, Saint Malo
# 2           2  Saint Malo  Parame, Saint Malo
# 3           3  Saint Malo  Parame, Saint Malo
# 4           4  Saint Malo  Parame, Saint Malo
#
#                                 hotel_name  \
# 0                                  Antinéa
# 1  Le RUELLAN charmant duplex proche plage
# 2  Le RUELLAN charmant duplex proche plage
# 3  Le RUELLAN charmant duplex proche plage
# 4  Le RUELLAN charmant duplex proche plage
#
#                                                 link  rating  \
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...     8.3
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 2  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 3  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
# 4  https://www.booking.com/hotel/fr/le-ruellan-ch...     8.3
#
#                              room_type    price      stay    guests  \
# 0  Family Room (2 Adults + 2 Children)  € 1,667  6 nights  2 adults
# 1                            Apartment    € 539  6 nights  2 adults
# 2                            Apartment    € 539  6 nights  2 adults
# 3                            Apartment    € 555  6 nights  2 adults
# 4                            Apartment    € 555  6 nights  2 adults
#
#                         room        description            location  \
# 0                 98 reviews  Free cancellation  1.6 km from centre
# 1  Managed by a private host  Free cancellation  3.3 km from centre
# 2  Managed by a private host  Free cancellation  3.3 km from centre
# 3  Managed by a private host  Free cancellation  3.3 km from centre
# 4  Managed by a private host  Free cancellation  3.3 km from centre
#
#                                             map_link  hotel_lat  hotel_lon  \
# 0  https://www.booking.com/hotel/fr/antinea.en-gb...  48.655543  -2.005139
# 1  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 2  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 3  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
# 4  https://www.booking.com/hotel/fr/le-ruellan-ch...  48.656487  -1.982275
#
#   city
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
